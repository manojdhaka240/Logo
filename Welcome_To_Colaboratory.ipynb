# %% [markdown]
# <a href="https://colab.research.google.com/github/manojdhaka240/Logo/blob/master/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files

# %%
# Load an audio file
audio_file = "a1.wav"
signal, sr = librosa.load(audio_file)
# Extracting  MFCC from signal
mfccs1 = librosa.feature.mfcc(y=signal, n_mfcc=13, sr=sr)  # this will look like 2-D matrix
# Visulaize MFCC 
plt.figure(figsize=(25, 10))
librosa.display.specshow(mfccs1, x_axis="time", sr=sr)
plt.colorbar(format="%+2.f")
plt.show()

# %%
mfccs1.shape
# Out:
# (13, 298)

# %%
mfccs1 = mfccs1.transpose()

# %%
mfccs1.shape
# Out:
# (298, 13)

# %%
audio_file1 = "a2.wav"
ipd.Audio(audio_file1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal, sr = librosa.load(audio_file1)
# Extracting  MFCC from signal
mfccs2 = librosa.feature.mfcc(y=signal, n_mfcc=13, sr=sr)  # this will look like 2-D matrix
# Visulaize MFCC 
plt.figure(figsize=(25, 10))
librosa.display.specshow(mfccs2, x_axis="time", sr=sr)
plt.colorbar(format="%+2.f")
plt.show()

# %%
mfccs2.shape
# Out:
# (13, 372)

# %%
mfccs2=mfccs2.transpose()

# %%
mfccs2.shape
# Out:
# (372, 13)

# %%
from fastdtw import fastdtw
from cdtw import pydtw
import fastdtw
import array
from timeit import default_timer as timer
from dtaidistance import dtw, dtw_visualisation as dtwvis

from fastdtw import fastdtw
from scipy.spatial.distance import euclidean
# !pip install dtaidistance
from dtaidistance import dtw
from dtaidistance import dtw_visualisation as dtwvis

# Distance between clip 1 and clip 2
# distance,path = fastdtw(mfccs1, mfccs2,dist=euclidean)
# print(distance)
# print(path)

distance1 = dtw.distance(mfccs1[0], mfccs2[0])
print(distance1)
# Out:
# 57.377748833122105
